# %%
# import statements needed for the rest of the script
from selenium import webdriver
import requests
import time
import csv

# %%
driver = webdriver.Firefox(executable_path = 'geckodriver\geckodriver.exe')

# %%
# lists for the combined article/image/url, and lists for each of those categories
items = []
x = []
y = []
z = []

# variable for article id
article_id = 0

for i in range(1):
    
    # set url link every iteration to get articles
    url = 'https://www.wwe.com/news/' + str(i + 1) + '/'
    print("Url page: " + str(url))
    driver.get(url)
    
    # give webdriver time to load page
    time.sleep(10)
    
    # get tags of articles
    atags = driver.find_elements_by_tag_name('a')
    
    # loop through the <a> tags
    for atag in atags:
        
        # url for article
        href = atag.get_attribute('href')
        
        # if article not in a list and it has the word "article" in it, append it
        if (('article' in str(href)) and (href not in x)):
            print(href)
            x.append(href)
        else:
            print("Href does not exist.")          
    
    # loop through each href
    for href in x:
        
        # set url link to an href
        driver.get(href)
        
        # wait a bit
        time.sleep(3)
        
        # get article name
        article = driver.find_element_by_class_name('wwe-article__hero--title').text
        
        # get image
        got_image = False
        imgs = driver.find_elements_by_tag_name('img')
        
        # bunch of conditions needed to get only what we want from the article titles, append article title
        if (not(str(article) == 'None') and (article not in y) and ('|' not in str(article)) and ('WWE NETWORK' not in str(article)) and ('START YOUR FREE MONTH' not in str(article)) and ('WWE NEWS' not in str(article)) and not(str(article).isnumeric())):
            print(article)
            y.append(article)
        else:
            print("Title does not exist.")
            y.append("Null")
        
        # loop through the <img> tags
        for img in imgs:
            src = img.get_attribute('srcset')
            if ((src not in z) and (not(src == 'null') or not(src == ''))):
                print("Has image.")
                z.append(src)
                got_image = True
                break
        
        if not(got_image):
            print("Image does not exist.")
            z.append("Null")
            
    for a in range(len(z)):
        if not(z[a] == 'Null'):
            z[a] = 'https://www.wwe.com' + z[a].split(" ")[0]
        y[a] = y[a].replace(",", "") 
        items.append([article_id, x[a], y[a], z[a]])
        article_id += 1
    
    print("Length of href: " + str(len(x)) + " Length of articles: " + str(len(y)) + " Length of src: " + str(len(z)))
    print("")
# Out:
# Url page: https://www.wwe.com/news/1/
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/becky-lynch-preview
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/the-new-day-feel-the-power-podcast-debuts-december-2-2019
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/survivor-series/article/how-to-watch-survivor-series-match-card-start-time-previews
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/seth-rollins-responds-cm-punk-wwe-backstage
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/editors-choice-eight-must-see-wargames-matches
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/r-truth-loses-24-7-title-to-wwe-corporate-employee-company-headquarters-wins-it-back
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/titus-o-neil-featured-on-cover-of-millennium-magazine
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/week-in-wwe-gifs-2019-11-19
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/nxt-takeover-wargames/article/pete-dunne-killian-dain-damian-priest-preview
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/shorty-g-wife-kristi-welcome-third-child
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/article/ciampa-walter-evolve-wrestling-detroit-chicago-dec-2019
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/undisputed-era-revival-preview
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/triple-h-open-door-raw-smackdown-preview
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-25/article/aj-styles-vs-humberto-carrillo-united-states-championship-match
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/rey-mysterio-agrees-no-holds-barred-no-disqualification-match-brock
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/raw-smackdown-nxt-brawl
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/episode-brief-8-wwe-raw-nov-18-2019
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article
# Has image.
# Seth Rollins def. Andrade via Disqualification
# Has image.
# Bobby Lashley def. No Way Jose
# Has image.
# Humberto Carrillo def. Karl Anderson
# Has image.
# Raw Women’s Champion Becky Lynch & Charlotte Flair def. The IIconics
# Has image.
# Roman Reigns, Mustafa Ali & Shorty G battle King Corbin, Dolph Ziggler & Robert Roode as blue brand tensions boil over
# Has image.
# Randy Orton, Rhea Ripley and “Stone Cold” Steve Austin to appear on WWE After the Bell
# Has image.
# WWE NXT UK TakeOver: Blackpool II sells out in two hours; Tickets coming soon for NXT UK 2020 shows in York, Coventry, Bournemouth and Glasgow
# Has image.
# NXT Live comes to Pittsburgh, Ohio, and Buffalo this January
# Has image.
# Final WCW Thunder episodes added to WWE Network
# Has image.
# See what's new this week on WWE Network
# Has image.
# NXT UK set to return to The Empress Ballroom for TakeOver: Blackpool II on Sunday, Jan. 12.
# Has image.
# Natalya to battle WWE Women’s Tag Team Champion Asuka
# Has image.
# Becky Lynch and Charlotte Flair to compete in tag team action on Raw
# Has image.
# Rey Mysterio to appear live on Raw before challenging Brock Lesnar at Survivor Series
# Has image.
# Lio Rush & Raul Mendoza def. Tony Nese & Ariya Daivari
# Has image.
# The Singh Brothers def. Tim Gange
# Has image.
# Angel Garza def. Gentleman Jack Gallagher
# Has image.
# Bray Wyatt and his Firefly Fun House friends get into a fierce debate with Daniel Bryan on “Miz TV”
# Has image.
# Sasha Banks, Nikki Cross, Carmella and Dana Brooke def. Rhea Ripley, Mia Yim, Tegan Nox & Dakota Kai
# Has image.
# Nikki Cross vs. Bayley ends in a No Contest
# Has image.
# Heavy Machinery def. ­­­­­­Kevin Tibbs & Kip Stevens
# Has image.
# The New Day vs. The Revival’s SmackDown Tag Team Championship Rematch ended in a No-Contest
# Has image.
# Bray Wyatt debuts new-look Universal Title on Friday Night SmackDown
# Has image.
# Braun Strowman laid waste to The B-Team after being berated by Drew Gulak
# Has image.
# Mustafa Ali & Shorty G def. Dolph Ziggler & Robert Roode
# Has image.
# King Corbin called out The Big Dog
# Has image.
# Length of href: 46 Length of articles: 46 Length of src: 46

# %%
for i in range(len(x)):
    print(str(x[i]) + ", " + str(y[i]) + ", " + str(z[i]))
    print("")
# Out:
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/becky-lynch-preview, Does Becky Lynch have something planned for NXT?, https://www.wwe.com
#
# https://www.wwe.com/article/the-new-day-feel-the-power-podcast-debuts-december-2-2019, The New Day: Feel the Power podcast set to debut Dec. 2, https://www.wwe.com/f/styles/wwe_16_9_xs/public/2019/10/20191014_FullMatch_Smackdown--de2d1ea74553845c828f95593d1bcfbc.jpg
#
# https://www.wwe.com/shows/survivor-series/article/how-to-watch-survivor-series-match-card-start-time-previews, WWE Survivor Series: match card  how to watch  previews  start time and more, https://www.wwe.com/f/styles/wwe_16_9_xs/public/2019/11/20191105_FullMatch_SS07--db98d270dec827b4a29fa2f1863628dc.jpg
#
# https://www.wwe.com/article/seth-rollins-responds-cm-punk-wwe-backstage, Seth Rollins responds to CM Punk’s WWE Backstage provocations, https://www.wwe.com/f/styles/wwe_16_9_xs/public/2019/11/20