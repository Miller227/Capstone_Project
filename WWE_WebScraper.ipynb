# %%
# import statements needed for the rest of the script
import pymysql
from selenium import webdriver
import requests
import time
import numpy
import csv

# %%
driver = webdriver.Firefox(executable_path = 'geckodriver.exe')

# %%
for i in range(1):
    
    # set url link every iteration to get articles
    url = 'https://www.wwe.com/news/' + str(i + 1) + '/'
    print("Url page: " + str(url))
    driver.get(url)
    
    # give webdriver time to load page
    time.sleep(10)
    
    # iterate through each item and get what you want from it
    atags = driver.find_elements_by_tag_name('a')
    #titles = driver.find_elements_by_tag_name('span')
    #imgs = driver.find_elements_by_tag_name('img')
    
    # debugging
    #print(len(atags))
    #print(len(imgs))
    #print(len(titles))
    
    items = []
    x = []
    y = []
    z = []
    
    article_id = 0
    
    for atag in atags:
        
        # url for article
        href = atag.get_attribute('href')
        
        if (('article' in str(href)) and (href not in x)):
            print(href)
            x.append(href)
        else:
            print("Href does not exist.")          
        
    for href in x:
        
        # iterate through the hrefs
        driver.get(href)
        
        # wait a bit
        time.sleep(3)
        
        # get article name
        article = driver.find_element_by_class_name('wwe-article__hero--title').text
        
        # get image
        got_image = False
        imgs = driver.find_elements_by_tag_name('img')
        
        if (not(str(article) == 'None') and (article not in y) and ('|' not in str(article)) and ('WWE NETWORK' not in str(article)) and ('START YOUR FREE MONTH' not in str(article)) and ('WWE NEWS' not in str(article)) and not(str(article).isnumeric())):
            print(article)
            y.append(article)
        else:
            print("Title does not exist.")
            y.append("Null")
            
        for img in imgs:
            src = img.get_attribute('srcset')
            if ((src not in z) and (not(src == 'null') or not(src == ''))):
                print("Has image.")
                z.append(src)
                got_image = True
                break
        
        if not(got_image):
            print("Image does not exist.")
            z.append("Null")
            
    for i in range(len(z)):
        z[i] = 'https://www.wwe.com' + z[i].split(" ")[0]
        items.append([article_id, x[i], y[i], z[i]])
        article_id += 1
    
    print("Length of href: " + str(len(x)) + " Length of articles: " + str(len(y)) + " Length of src: " + str(len(z)))
    print("")
# Out:
# Url page: https://www.wwe.com/news/1/
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/editors-choice-eight-must-see-wargames-matches
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/r-truth-loses-24-7-title-to-wwe-corporate-employee-company-headquarters-wins-it-back
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/titus-o-neil-featured-on-cover-of-millennium-magazine
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/week-in-wwe-gifs-2019-11-19
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/nxt-takeover-wargames/article/pete-dunne-killian-dain-damian-priest-preview
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/shorty-g-wife-kristi-welcome-third-child
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/article/ciampa-walter-evolve-wrestling-detroit-chicago-dec-2019
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/undisputed-era-revival-preview
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/triple-h-open-door-raw-smackdown-preview
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-25/article/aj-styles-vs-humberto-carrillo-united-states-championship-match
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/rey-mysterio-agrees-no-holds-barred-no-disqualification-match-brock
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/raw-smackdown-nxt-brawl
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/episode-brief-8-wwe-raw-nov-18-2019
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/triple-h-kevin-owens-undisputed-era-nxt-superstars
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/erick-rowan-def-alex-malcom
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/buddy-murphy-def-akira-tozawa
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/seth-rollins-def-andrade-via-disqualification
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/bobby-lashley-def-no-way-jose
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/humberto-carrillo-def-karl-anderson
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/becky-lynch-charlotte-flair-def-the-iiconics
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/article/roman-reigns-mustafa-ali-shorty-g-king-corbin-dolph-ziggler-robert-roode
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwe-after-the-bell/article/stone-cold-steve-austin-randy-orton-rhea-ripley-after-the-bell
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/nxtuk/article/get-tickets-for-upcoming-nxt-uk-shows-in-2020
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/article/nxt-live-pittsburgh-ohio-buffalo-january-2020
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/article/final-wcw-thunder-episodes-added-to-wwe-network
# Href does not exist.
# https://www.wwe.com/article/whats-new-wwe-network
# Href does not exist.
# https://www.wwe.com/shows/nxtuk/article/nxt-uk-set-to-return-to-the-empress-ballroom-for-takeover-blackpool-ii-on-jan-12
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/natalya-to-battle-wwe-womens-tag-team-champion-asuka
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/becky-lynch-charlotte-flair-compete-in-tag-team-action
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/rey-mysterio-live-on-raw-before-challenging-brock-lesnar
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwe-205-live/2019-11-15/article/lio-rush-raul-mendoza-def-tony-nese-ariya-daivari
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwe-205-live/2019-11-15/article/the-singh-brothers-def-tim-gange
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwe-205-live/2019-11-15/article/angel-garza-def-gentleman-jack-gallagher
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/miz-tv
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/sasha-banks-nikki-cross-carmella-and-dana-brooke-vs-rhea-ripley
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/nikki-cross-vs-bayley
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/heavy-machinery-def-local-athletes
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/the-new-day-vs-the-revival
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/article/bray-wyatt-reveals-new-look-universal-title
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/braun-strowman-vs-drew-gulak
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/mustafa-ali-shorty-g-vs-dolph-ziggler-robert-roode
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/smackdown/2019-11-15/article/king-corbin-calls-out-the-big-dog
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/raw/2019-11-18/article/seth-rollins-vs-andrade
# Href does not exist.
# Href does not exist.
# https://www.wwe.com/shows/wwenxt/article/nxt-live-events-milwaukee-indianapolis-rescheduled
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Href does not exist.
# Editors’ Choice: Eight must-see WarGames Matches
# Has image.
# R-Truth loses 24/7 Title to WWE corporate employee at company headquarters before winning it back
# Has image.
# Titus O’Neil featured on the cover of Millennium Magazine
# Has image.
# This week in WWE GIFs: Say “Yes!” with Bray Wyatt and more!
# Has image.
# Pete Dunne vs. Killian Dain vs. Damian Priest (Winner challenges NXT Champion Adam Cole at Survivor Series)
# Has image.
# Shorty G and wife welcome third child
# Image does not exist.
# Tommaso Ciampa and WWE United Kingdom Champion WALTER to appear for EVOLVE Wrestling in Detroit and Chicago
# Has image.
# The Undisputed ERA take on The Revival in tag team action
# Has image.
# Will Raw or SmackDown take Triple H up on his offer?
# Image does not exist.
# Humberto Carrillo to challenge AJ Styles for the United States Championship on next week’s Raw
# Image does not exist.
# Rey Mysterio agreed to a No Holds Barred, No Disqualification Match against Brock Lesnar
# Has image.
# Randy Orton & Ricochet def. Raw Tag Team Champions The Viking Raiders via Disqualification when the Raw, SmackDown and NXT rosters brawled
# Has image.
# WWE Women’s Tag Team Champion Asuka def. Natalya
# Has image.
# Triple H tried to recruit Kevin Owens to NXT
# Image does not exist.
# Erick Rowan def. Alex Malcom

# %%
for i in range(len(x)):
    print(str(x[i]) + ", " + str(y[i]) + ", " + str(z[i]))
    print("")
# Out:
# https://www.wwe.com/article/editors-choice-eight-must-see-wargames-matches, Editors’ Choice: Eight must-see WarGames Matches,
#
# https://www.wwe.com/article/r-truth-loses-24-7-title-to-wwe-corporate-employee-company-headquarters-wins-it-back, R-Truth loses 24/7 Title to WWE corporate employee at company headquarters before winning it back, Null
#
# https://www.wwe.com/article/titus-o-neil-featured-on-cover-of-millennium-magazine, Titus O’Neil featured on the cover of Millennium Magazine, /f/styles/wwe_16_9_xl/public/all/2019/11/20191119_MilleniumMag_Titus_FC--ebf54cc05c2e1f1f9334e5dc447f2feb.jpg 1125w
#
# https://www.wwe.com/article/week-in-wwe-gifs-2019-11-19, This week in WWE GIFs: Say “Yes!” with Bray Wyatt and more!, /f/styles/wwe_16_9_xl/public/all/2019/11/171_SD_11152019dog_2472--2fba0caab065cbc18cb32960dd68c5aa.jpg 1125w
#
# https://www.wwe.com/shows/wwenxt/nxt-takeover-wargames/article/pete-dunne-killian-dain-damian-priest-preview, Pete Dunne vs. Killian Dain vs. Damian Priest (Winner challenges NXT Champion Adam Cole at Survivor Series), /f/styles/wwe_16_9_xs/public/2019/11/20191030_FullMatch_WarGames18_DreamCiampa--eba5fb43397979a7f803cf9c0142415c.jpg 480w
#
# https://www.wwe.com/article/shorty-g-wife-kristi-welcome-third-child, Shorty G and wife welcome third child, Null
#
# https://www.wwe.com/shows/wwenxt/article/ciampa-walter-evolve-wrestling-detroit-chicago-dec-2019, Tommaso Ciampa and WWE United Kingdom Champion WALTER to appear for EVOLVE Wrestling in Detroit and Chicago, Null
#
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/undisputed-era-revival-preview, The Undisputed ERA take on The Revival in tag team action, Null
#
# https://www.wwe.com/shows/wwenxt/2019-11-20/article/triple-h-open-door-raw-smackdown-preview, Will Raw or SmackDown take Triple H up on his offer?, /f/styles/wwe_16_9_xs/public/2019/11/20191030_FullMatch_--4ca27459be754973ac8456bdbe753800.jpg 480w
#
# https://www.wwe.com/shows/raw/2019-11-25/article/aj-styles-vs-humberto-carrillo-united-states-championship-match, Humberto Carrillo to challenge AJ Styles for the United States Championship on next week’s Raw, /f/styles/wwe_16_9_xl/public/all/2019/11/20191118_Raw_AJ_Humbeto--72ad2d201d6ab31614c1ed26e930024e.jpg 1125w
#
# https://www.wwe.com/shows/raw/2019-11-18/article/rey-mysterio-agrees-no-holds-barred-no-disqualification-match-brock, Rey Mysterio agreed to a No Holds Barred, No Disqualification Match against Brock Lesnar, Null
#
# https://www.wwe.com/shows/raw/2019-11-18/article/raw-smackdown-nxt-brawl, Randy Orton & Ricochet def. Raw Tag Team Champions The Viking Raiders via Disqualification when the Raw, SmackDown and NXT rosters brawled, Null
#
# https://www.wwe.com/shows/raw/2019-11-18/article/episode-brief-8-wwe-raw-nov-18-2019, WWE Women’s Tag Team Champion Asuka def. Natalya, /f/styles/wwe_16_9_xs/public/2019/11/vmssg_3t9cV--c72fe411ad22e5a389a5b634a95efb2e.jpg 480w
#
# https://www.wwe.com/shows/raw/2019-11-18/article/triple-h-kevin-owens-undisputed-era-nxt-superstars, Triple H tried to recruit Kevin Owens to NXT, /f/styles/wwe_16x9_xl/public/2019/11/20191118_RAW_KO_TripleH--2112270ecc03c825be86ab0c61397079.jpg 1920w
#
# https://www.wwe.com/shows/raw/2019-11-18/article/erick-rowan-def-alex-malcom, Erick Rowan def. Alex Malcom, /f/styles/wwe_16_9_xs/public/2019/11/20191118_RAW_247--5286265f00b19cbbfdeda2c415fe14c5.jpg 480w
#
# https://www.wwe.com/shows/raw/2019-11-18/article/buddy-murphy-def-akira-tozawa, Buddy Murphy def. Akira Tozawa, /f/styles/wwe_16_9_xl/public/2019/11/20191118_RAW_Tozawa_Murphy--7c5df42ed526e21aca58799cc2039f12.jpg 1125w
#
# https://www.wwe.com/shows/raw/2019-11-18/article/seth-rollins-def-andrade-via-disqualification, Seth Rollins def. Andrade via Disqualification, Null
#
# https://www.wwe.com/shows/raw/2019-11-18/article/bobby-lashley-def-no-way-jose, Bobby Lashley def. No Way Jose, /f/styles/wwe_16_9_xl/public/2019/11/20191118_RAW_Lana_Bobby--81569cb9f2d71ed85841b37ba363e8e2.jpg 1125w
#
# https://www.wwe.com/shows/raw/2019-11-18/article/humberto-carrillo-def-karl-anderson, Humberto Carrillo def. Karl Anderson, /f/styles/wwe_16_9_xl/public/2019/11/20191118_RAW_Karl_Humberto--76fb68fc54d8e61628c49e8e000f4b94.jpg 1125w
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-40db9e999a78> in <module>
#       1 for i in range(len(x)):
# ----> 2     print(str(x[i]) + ", " + str(y[i]) + ", " + str(z[i]))
#       3     print("")
#
# IndexError: list index out of range

# %%
fields = ('Article ID', 'Article URL', 'Article Title', 'Article Image URL')

with open('WWE_Data.csv', 'w', newline = '') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(fields)
    writer.writerows(items)
